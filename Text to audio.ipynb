# %%
pip install gTTS
# Out:
# Requirement already satisfied: gTTS in c:\users\ashlin\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: requests in c:\users\ashlin\anaconda3\lib\site-packages (from gTTS) (2.25.1)
# Requirement already satisfied: six in c:\users\ashlin\anaconda3\lib\site-packages (from gTTS) (1.15.0)
# Requirement already satisfied: click in c:\users\ashlin\anaconda3\lib\site-packages (from gTTS) (7.1.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ashlin\anaconda3\lib\site-packages (from requests->gTTS) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ashlin\anaconda3\lib\site-packages (from requests->gTTS) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ashlin\anaconda3\lib\site-packages (from requests->gTTS) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashlin\anaconda3\lib\site-packages (from requests->gTTS) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS('hello.. how are you')
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
